# %%
import pandas as pd
import datetime as dt

# %%
base = pd.read_csv('2024-divvy-tripdata.csv')

# %%
base.shape
# Out:
# (5860568, 13)

# %%
base.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C1D650626C8C899A  electric_bike  2024-01-12 15:30:27  2024-01-12 15:37:59
# 1  EECD38BDB25BFCB0  electric_bike  2024-01-08 15:45:46  2024-01-08 15:52:59
# 2  F4A9CE78061F17F7  electric_bike  2024-01-27 12:27:19  2024-01-27 12:35:19
# 3  0A0D9E15EE50B171   classic_bike  2024-01-29 16:26:17  2024-01-29 16:56:06
# 4  33FFC9805E3EFF9A   classic_bike  2024-01-31 05:43:23  2024-01-31 06:09:35
#
#            start_station_name start_station_id           end_station_name  \
# 0           Wells St & Elm St     KA1504000135   Kingsbury St & Kinzie St
# 1           Wells St & Elm St     KA1504000135   Kingsbury St & Kinzie St
# 2           Wells St & Elm St     KA1504000135   Kingsbury St & Kinzie St
# 3      Wells St & Randolph St     TA1305000030  Larrabee St & Webster Ave
# 4  Lincoln Ave & Waveland Ave            13253   Kingsbury St & Kinzie St
#
# ...

# %%
base.nunique()
# Out:
# ride_id               5860357
# rideable_type               3
# started_at            5649602
# ended_at              5652165
# start_station_name       1808
# start_station_id         1763
# end_station_name         1815
# end_station_id           1768
# start_lat              531777
# start_lng              513647
# end_lat                  2782
# end_lng                  2802
# member_casual               2
# dtype: int64

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5860568 entries, 0 to 5860567
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 581.3+ MB

# %%
base.groupby('member_casual',)['ride_id'].count()
# Out:
# member_casual
# casual    2151658
# member    3708910
# Name: ride_id, dtype: int64

# %%
base.groupby('rideable_type')['ride_id'].count()
# Out:
# rideable_type
# classic_bike        2735636
# electric_bike       2980595
# electric_scooter     144337
# Name: ride_id, dtype: int64

# %%
base.groupby(['member_casual','rideable_type'])['ride_id'].count()
# Out:
# member_casual  rideable_type
# casual         classic_bike         974966
#                electric_bike       1091477
#                electric_scooter      85215
# member         classic_bike        1760670
#                electric_bike       1889118
#                electric_scooter      59122
# Name: ride_id, dtype: int64

# %%
base.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name    1073951
# start_station_id      1073951
# end_station_name      1104653
# end_station_id        1104653
# start_lat                   0
# start_lng                   0
# end_lat                  7232
# end_lng                  7232
# member_casual               0
# dtype: int64

# %%
display(base[base['end_lat'].isnull()])
# Out:
#                   ride_id rideable_type               started_at  \
# 75488    16D623E15D50BDC4  classic_bike      2024-01-17 07:27:37
# 75518    4AED4912A1C82E62  classic_bike      2024-01-10 13:22:32
# 75539    E6EB2D2AB728EBCD  classic_bike      2024-01-16 07:56:06
# 77579    A322C307E03880C0  classic_bike      2024-01-16 12:39:16
# 77609    F1E68C2E598C583F  classic_bike      2024-01-26 10:56:37
# ...                   ...           ...                      ...
# 5859626  528762D81B7D7384  classic_bike  2024-12-13 23:38:45.218
# 5859728  B859928FAA610509  classic_bike  2024-12-13 21:04:14.855
# 5859787  53337D65C2F0810F  classic_bike  2024-12-24 12:24:55.002
# 5860320  A1FEE6CB062E7BCB  classic_bike  2024-11-30 22:10:47.714
# 5860346  CAD9F49C3C4230BA  classic_bike  2024-12-16 21:43:54.582
#
#                         ended_at             start_station_name  \
# 75488        2024-01-18 08:27:28              Wells St & Elm St
# ...

# %%
base[base['end_lat'].isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7232 entries, 75488 to 5860346
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             7232 non-null   object
#  1   rideable_type       7232 non-null   object
#  2   started_at          7232 non-null   object
#  3   ended_at            7232 non-null   object
#  4   start_station_name  7232 non-null   object
#  5   start_station_id    7232 non-null   object
#  6   end_station_name    0 non-null      object
#  7   end_station_id      0 non-null      object
#  8   start_lat           7232 non-null   float64
#  9   start_lng           7232 non-null   float64
#  10  end_lat             0 non-null      float64
#  11  end_lng             0 non-null      float64
#  12  member_casual       7232 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 791.0+ KB

# %%
base[base['end_station_name'].isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1104653 entries, 75478 to 5860567
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ride_id             1104653 non-null  object
#  1   rideable_type       1104653 non-null  object
#  2   started_at          1104653 non-null  object
#  3   ended_at            1104653 non-null  object
#  4   start_station_name  578308 non-null   object
#  5   start_station_id    578308 non-null   object
#  6   end_station_name    0 non-null        object
#  7   end_station_id      0 non-null        object
#  8   start_lat           1104653 non-null  float64
#  9   start_lng           1104653 non-null  float64
#  10  end_lat             1097421 non-null  float64
#  11  end_lng             1097421 non-null  float64
#  12  member_casual       1104653 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 118.0+ MB

# %%
base[base['end_station_name'].isnull()].describe()
# Out:
#           start_lat     start_lng       end_lat       end_lng
# count  1.104653e+06  1.104653e+06  1.097421e+06  1.097421e+06
# mean   4.190989e+01 -8.765240e+01  4.191067e+01 -8.765265e+01
# std    4.849711e-02  3.098990e-02  9.147408e-02  2.566535e-01
# min    4.164000e+01 -8.791000e+01  1.606000e+01 -1.440500e+02
# 25%    4.188473e+01 -8.767000e+01  4.189000e+01 -8.767000e+01
# 50%    4.191000e+01 -8.765000e+01  4.191000e+01 -8.765000e+01
# 75%    4.194000e+01 -8.763000e+01  4.194000e+01 -8.763000e+01
# max    4.207000e+01 -8.752000e+01  8.796000e+01  1.525300e+02

# %%
base[base['end_station_name'] == 'Lincoln Ave & Roscoe St*']
# Out:
#                   ride_id  rideable_type               started_at  \
# 76       B0F9925C73BEB136  electric_bike      2024-01-29 18:50:54
# 79       C24AD33E4203FE44   classic_bike      2024-01-21 09:01:01
# 382      A5E8A630C566FDF7  electric_bike      2024-01-07 15:37:01
# 387      BA1D2CDC9B56367F   classic_bike      2024-01-30 15:53:30
# 388      56FFB570BFA5D71C   classic_bike      2024-01-18 20:56:33
# ...                   ...            ...                      ...
# 5687538  681ADC29745C0D10   classic_bike  2024-12-10 17:28:39.774
# 5687542  6E648FECAA3539AD   classic_bike  2024-12-12 13:11:34.282
# 5687550  72AA02379BFD9658  electric_bike  2024-12-20 10:29:28.794
# 5687554  44CD42113EC582DA   classic_bike  2024-12-22 12:37:58.676
# 5687557  266A47ABFEE71A9A   classic_bike  2024-12-28 08:23:10.102
#
#                         ended_at            start_station_name  \
# 76           2024-01-29 19:03:24    Clarendon Ave & Junior Ter
# ...

# %%
base[base.duplicated(subset='ride_id')]
# Out:
#                   ride_id  rideable_type               started_at  \
# 1697610  3B5CE4D8B3EE6ED8  electric_bike  2024-05-31 23:50:04.153
# 1697634  60B4DDFF369931B2  electric_bike  2024-05-31 23:51:07.398
# 1697659  1D8856396862BE62  electric_bike  2024-05-31 23:56:12.241
# 1698918  B1B9E66D2E7C383D   classic_bike  2024-05-31 11:50:26.806
# 1702774  9FF6FFB668739B47  electric_bike  2024-05-31 23:53:26.419
# ...                   ...            ...                      ...
# 2397298  2C2CD7C3DCBC3C39   classic_bike  2024-05-31 01:09:43.561
# 2399469  532780A49B9089CD  electric_bike  2024-05-31 23:57:45.184
# 2400500  9B43F7CB54CFB914  electric_bike  2024-05-31 23:34:26.101
# 2401823  7817F106775A6E24   classic_bike  2024-05-31 18:01:22.459
# 2402847  A5CEDF5535693FFB  electric_bike  2024-05-31 23:31:22.041
#
#                         ended_at                        start_station_name  \
# 1697610  2024-06-01 00:06:08.273                                       NaN
# ...

# %%
base[base['ride_id'] == '3B5CE4D8B3EE6ED8']
# Out:
#                   ride_id  rideable_type               started_at  \
# 1337045  3B5CE4D8B3EE6ED8  electric_bike      2024-05-31 23:50:04
# 1697610  3B5CE4D8B3EE6ED8  electric_bike  2024-05-31 23:50:04.153
#
#                         ended_at start_station_name start_station_id  \
# 1337045      2024-06-01 00:06:08                NaN              NaN
# 1697610  2024-06-01 00:06:08.273                NaN              NaN
#
#         end_station_name end_station_id  start_lat  start_lng  end_lat  \
# 1337045              NaN            NaN      41.98     -87.67    41.98
# 1697610              NaN            NaN      41.98     -87.67    41.98
#
#          end_lng member_casual
# 1337045   -87.67        casual
# 1697610   -87.67        casual

# %%
base[base['ride_id'] == '60B4DDFF369931B2']
# Out:
#                   ride_id  rideable_type               started_at  \
# 1337115  60B4DDFF369931B2  electric_bike      2024-05-31 23:51:07
# 1697634  60B4DDFF369931B2  electric_bike  2024-05-31 23:51:07.398
#
#                         ended_at start_station_name start_station_id  \
# 1337115      2024-06-01 00:25:37                NaN              NaN
# 1697634  2024-06-01 00:25:37.453                NaN              NaN
#
#         end_station_name end_station_id  start_lat  start_lng  end_lat  \
# 1337115              NaN            NaN      41.88     -87.65    41.97
# 1697634              NaN            NaN      41.88     -87.65    41.97
#
#          end_lng member_casual
# 1337115   -87.68        casual
# 1697634   -87.68        casual

# %%
inicio = pd.to_datetime(base['started_at'], format='mixed').dt.date.min()
print(inicio)
# Out:
# 2024-01-01

# %%
fim = pd.to_datetime(base['started_at'], format='mixed').dt.date.max()
print(fim)
# Out:
# 2024-12-31
